# %%
import pandas as pd
import os

def analyser_structure_fichier():
    print("=== ANALYSE DE LA STRUCTURE DU FICHIER ===")
    
    chemin_fichier = 'hackaton_projet_W3D5/DATASET/plats_populaires_ingredients.csv'
    
    try:
        # Lecture du fichier avec différents séparateurs
        print("\nTentative de lecture avec différents séparateurs...")
        
        # Essai avec point-virgule
        df_semicolon = pd.read_csv(chemin_fichier, sep=';', nrows=5)
        print("\nLecture avec point-virgule :")
        print("Colonnes trouvées :", df_semicolon.columns.tolist())
        print("\nPremières lignes :")
        print(df_semicolon.head(2))
        
        # Essai avec virgule
        df_comma = pd.read_csv(chemin_fichier, sep=',', nrows=5)
        print("\nLecture avec virgule :")
        print("Colonnes trouvées :", df_comma.columns.tolist())
        print("\nPremières lignes :")
        print(df_comma.head(2))
        
        # Affichage des informations détaillées
        print("\nInformations détaillées du DataFrame :")
        print(df_semicolon.info())
        
        # Vérification des valeurs nulles
        print("\nVérification des valeurs manquantes :")
        print(df_semicolon.isnull().sum())
        
    except Exception as e:
        print(f"Erreur lors de l'analyse : {e}")

# Exécution
if __name__ == "__main__":
    analyser_structure_fichier()
# Out:
# === ANALYSE DE LA STRUCTURE DU FICHIER ===
#
# Tentative de lecture avec différents séparateurs...
#
# Lecture avec point-virgule :
# Colonnes trouvées : ['Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients']
#
# Premières lignes :
#   Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients
# 0  Beef Brisket Pot Roast,ÉTATS-UNIS,Viande,Beef ...
# 1  Big Mac,ÉTATS-UNIS,Fast-food,Minced Beef (400g...
#
# Lecture avec virgule :
# Colonnes trouvées : ['Plat', 'Pays', 'Catégorie', 'Ingrédients', 'Nombre_Ingrédients']
#
# Premières lignes :
#                      Plat        Pays  Catégorie  \
# 0  Beef Brisket Pot Roast  ÉTATS-UNIS     Viande
# 1                 Big Mac  ÉTATS-UNIS  Fast-food
#
#                                          Ingrédients  Nombre_Ingrédients
# 0  Beef Brisket (4-5 pound) | Salt (Dash) | Onion...                  11
# 1  Minced Beef (400g) | Olive Oil (2 tbs) | Sesam...                  14
#
# Informations détaillées du DataFrame :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients  5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes
# None
#
# Vérification des valeurs manquantes :
# Plat,Pays,Catégorie,Ingrédients,Nombre_Ingrédients    0
# dtype: int64

# %%
import os
import pandas as pd
import requests
import time
from typing import Dict, List, Tuple

class NutrientAnalyzer:
    def __init__(self):
        self.API_KEY = "V47bTvrwdE63sv3FPzRPbyo30fxLmg4cJnc6tWol"
        self.base_url = "https://api.nal.usda.gov/fdc/v1/foods/search"
        
        # Nutriments à analyser
        self.nutriments_cibles = {
            'Protein': 'Protéines (g)',
            'Total lipid (fat)': 'Lipides (g)',
            'Carbohydrate, by difference': 'Glucides (g)',
            'Energy': 'Calories (kcal)',
            'Fiber, total dietary': 'Fibres (g)',
            'Sugars, total including NLEA': 'Sucres (g)'
        }
        
        # Portions standard pour les ingrédients
        self.portions_standard = {
            # Viandes et volailles
            'chicken breast': 170,    # g par poitrine
            'chicken legs': 230,      # g par cuisse
            'chicken thighs': 160,    # g par haut de cuisse
            'chicken': 150,           # g par portion standard
            'beef': 200,             # g par portion
            'beef brisket': 450,     # g par portion
            'pork': 200,             # g par portion
            'bacon': 30,             # g par tranche
            'lamb': 175,             # g par portion
            'minced beef': 100,      # g par portion
            'duck': 200,             # g par portion
            'prawns': 30,            # g par pièce
            
            # Légumes
            'onion': 150,            # g par oignon moyen
            'garlic': 5,             # g par gousse
            'carrot': 120,           # g par carotte
            'potato': 150,           # g par pomme de terre
            'tomato': 120,           # g par tomate
            'mushroom': 15,          # g par champignon
            'pepper': 120,           # g par poivron
            'lettuce': 50,           # g par portion
            'courgette': 200,        # g par courgette
            'zucchini': 200,         # g par courgette
            'aubergine': 250,        # g par aubergine
            'spring onion': 15,      # g par oignon vert
            'scallion': 15,          # g par oignon vert
            'celery': 40,            # g par branche
            'bean sprouts': 50,      # g par portion
            'peas': 80,              # g par portion
            'green beans': 100,      # g par portion
            'cabbage': 150,          # g par portion
            
            # Fromages et produits laitiers
            'cheese': 30,            # g par tranche
            'mozzarella': 125,       # g par boule
            'parmesan': 25,          # g par portion
            'feta': 50,              # g par portion
            'cream': 240,            # ml par tasse
            'heavy cream': 240,      # ml par tasse
            'greek yogurt': 170,     # g par portion
            'butter': 14,            # g par cuillère à soupe
            
            # Féculents
            'rice': 75,              # g cru par portion
            'pasta': 85,             # g cru par portion
            'noodles': 85,           # g cru par portion
            'flour': 120,            # g par tasse
            'bread': 30,             # g par tranche
            'burger bun': 60,        # g par pain
            
            # Herbes et épices
            'basil': 5,              # g par portion
            'parsley': 5,            # g par portion
            'thyme': 2,              # g par branche
            'rosemary': 2,           # g par branche
            'oregano': 2,            # g par cuillère à soupe
            'ginger': 15,            # g par morceau
            'coriander': 5,          # g par portion
            'mint': 5,               # g par portion
            'bay leaf': 1,           # g par feuille
            
            # Sauces et condiments
            'soy sauce': 15,         # ml par cuillère à soupe
            'fish sauce': 15,        # ml par cuillère à soupe
            'oyster sauce': 15,      # ml par cuillère à soupe
            'tomato puree': 15,      # g par cuillère à soupe
            'mustard': 15,           # g par cuillère à soupe
            'mayonnaise': 14,        # g par cuillère à soupe
            
            # Autres
            'egg': 50,               # g par œuf
            'tofu': 100,             # g par portion
            'olive oil': 15,         # ml par cuillère à soupe
            'stock': 240,            # ml par tasse
            'water': 240,            # ml par tasse
            'wine': 240,             # ml par tasse
            'sugar': 4,              # g par cuillère à café
            'honey': 21,             # g par cuillère à soupe
            'yeast': 7,              # g par sachet
        }
        
        # Conversions de base
        self.conversions = {
            # Volumes
            'cup': 240,              # ml
            'cups': 240,             # ml
            'tsp': 5,                # ml
            'teaspoon': 5,           # ml
            'tbsp': 15,              # ml
            'tablespoon': 15,        # ml
            'tbs': 15,               # ml
            'fluid oz': 30,          # ml
            'fl oz': 30,             # ml
            'pint': 473,             # ml
            'quart': 946,            # ml
            'gallon': 3785,          # ml
            'ml': 1,                 # ml
            'l': 1000,               # ml
            
            # Poids
            'oz': 28.35,             # g
            'ounce': 28.35,          # g
            'lb': 453.6,             # g
            'pound': 453.6,          # g
            'kg': 1000,              # g
            'g': 1,                  # g
            
            # Portions spécifiques
            'slice': 30,             # g (pour pain, fromage)
            'piece': 1,              # unité
            'clove': 5,              # g (pour l'ail)
            'sprig': 2,              # g (pour herbes fraîches)
            'bunch': 30,             # g (pour herbes)
            'dash': 0.5,             # ml/g
            'pinch': 0.25,           # ml/g
            'handful': 30,           # g
            'large': 1.5,            # multiplicateur
            'small': 0.75,           # multiplicateur
            'medium': 1,             # multiplicateur
        }
        
        # Chemins des fichiers
        self.chemin_base = "/Users/ludovicveltz/Documents/Bootcamp_GENAI_2025/Crashcourse/hackaton_projet_W3D5/DATASET"
        self.chemin_fichier = os.path.join(self.chemin_base, "plats_populaires_ingredients.csv")
        self.chemin_sortie = os.path.join(self.chemin_base, "plats_populaires_nutriments_complet.csv")

    def normaliser_quantite(self, quantite_str: str, ingredient: str) -> Tuple[float, str]:
        """Normalise les quantités en unités standard"""
        quantite_str = quantite_str.lower()
        multiplicateur = 1
        
        # Vérification des modificateurs de taille
        for taille in ['large', 'small', 'medium']:
            if taille in quantite_str:
                multiplicateur = self.conversions[taille]
                quantite_str = quantite_str.replace(taille, '').strip()
        
        try:
            # Extraction du nombre
            nombre = float(''.join([c for c in quantite_str.split()[0] if c.isdigit() or c == '.' or c == '/']))
            if '/' in quantite_str.split()[0]:
                # Gestion des fractions
                num, denom = quantite_str.split()[0].split('/')
                nombre = float(num) / float(denom)
            
            # Détection de l'unité
            for unite, conversion in self.conversions.items():
                if unite in quantite_str:
                    if unite in ['cup', 'cups', 'tsp', 'tbsp', 'tbs', 'fluid oz', 'fl oz', 'pint', 'quart', 'gallon', 'ml', 'l']:
                        return nombre * conversion * multiplicateur, 'ml'
                    return nombre * conversion * multiplicateur, 'g'
            
            # Si pas d'unité trouvée, utiliser les portions standard
            for ing_key, portion in self.portions_standard.items():
                if ing_key in ingredient.lower():
                    return nombre * portion * multiplicateur, 'g'
            
            return nombre * multiplicateur, 'portion'
            
        except:
            # Si échec de conversion, retourner une portion standard
            for ing_key, portion in self.portions_standard.items():
                if ing_key in ingredient.lower():
                    return portion * multiplicateur, 'g'
            return 1 * multiplicateur, 'portion'

    def extraire_ingredients_et_quantites(self, ingredients_str: str) -> List[Tuple[str, float, str]]:
        """Extrait les ingrédients avec leurs quantités et unités"""
        if pd.isna(ingredients_str) or ingredients_str == 'Non disponible':
            return []
        
        ingredients_list = []
        for ing in ingredients_str.split('|'):
            ing = ing.strip()
            if '(' in ing and ')' in ing:
                nom = ing.split('(')[0].strip()
                quantite_str = ing.split('(')[1].split(')')[0].strip()
                qte, unite = self.normaliser_quantite(quantite_str, nom)
                ingredients_list.append((nom, qte, unite))
            else:
                # Recherche d'une portion standard
                for ing_key, portion in self.portions_standard.items():
                    if ing_key in ing.lower():
                        ingredients_list.append((ing, portion, 'g'))
                        break
                else:
                    ingredients_list.append((ing, 1, 'portion'))
        
        return ingredients_list

    def rechercher_nutriments(self, ingredient: str, quantite: float, unite: str) -> Dict:
        """Recherche les nutriments pour un ingrédient donné"""
        params = {
            'api_key': self.API_KEY,
            'query': ingredient,
            'pageSize': 1,
            'dataType': ['Foundation', 'Survey (FNDDS)']
        }
        
        try:
            response = requests.get(self.base_url, params=params)
            if response.status_code == 200:
                data = response.json()
                if data.get('foods'):
                    nutrients = data['foods'][0]['foodNutrients']
                    nutriments = {}
                    
                    for n in nutrients:
                        if n.get('nutrientName') in self.nutriments_cibles:
                            valeur = n.get('value', 0)
                            # Conversion selon l'unité
                            if unite in ['g', 'ml']:
                                valeur = valeur * (quantite / 100)
                            else:  # portion
                                valeur = valeur * quantite
                            nutriments[n['nutrientName']] = valeur
                    
                    return nutriments
            return {}
        except Exception as e:
            print(f"Erreur pour {ingredient}: {e}")
            return {}

    def valider_nutriments(self, nutriments: Dict) -> Dict:
        """Valide et ajuste les valeurs nutritionnelles"""
        ratios = {
            'Protéines (g)': (0, 300),    # max 300g par plat
            'Lipides (g)': (0, 250),      # max 250g par plat
            'Glucides (g)': (0, 400),     # max 400g par plat
            'Calories (kcal)': (0, 3000), # max 3000 kcal par plat
            'Fibres (g)': (0, 50),        # max 50g par plat
            'Sucres (g)': (0, 100)        # max 100g par plat
        }
        
        for nutriment, (min_val, max_val) in ratios.items():
            if nutriment in nutriments:
                nutriments[nutriment] = max(min_val, min(nutriments[nutriment], max_val))
        
        return nutriments

    def analyser_plats(self):
        """Analyse nutritionnelle des plats"""
        try:
            df = pd.read_csv(self.chemin_fichier, sep=',')
            print(f"Dataset chargé avec succès : {len(df)} plats")
            
            resultats = []
            total_plats = len(df)
            
            for index, row in df.iterrows():
                plat = row['Plat'].strip()
                print(f"\nAnalyse du plat {index + 1}/{total_plats} : {plat}")
                
                ingredients = self.extraire_ingredients_et_quantites(row['Ingrédients'])
                nutriments_totaux = {value: 0 for value in self.nutriments_cibles.values()}
                
                for ingredient, quantite, unite in ingredients:
                    print(f"  Analyse de : {ingredient} ({quantite} {unite})")
                    nutriments = self.rechercher_nutriments(ingredient, quantite, unite)
                    
                    for api_name, fr_name in self.nutriments_cibles.items():
                        if api_name in nutriments:
                            nutriments_totaux[fr_name] += nutriments[api_name]
                    
                    time.sleep(1)  # Respect des limites de l'API
                
                # Validation des nutriments
                nutriments_totaux = self.valider_nutriments(nutriments_totaux)
                
                resultat = {
                    'Plat': plat,
                    'Pays': row['Pays'].strip(),
                    'Catégorie': row['Catégorie'].strip()
                }
                resultat.update(nutriments_totaux)
                
                resultats.append(resultat)
                
                # Sauvegarde temporaire
                if (index + 1) % 5 == 0:
                    self.sauvegarder_resultats_temporaires(resultats)

            return self.finaliser_analyse(resultats)

        except Exception as e:
            print(f"Erreur lors de l'analyse : {e}")
            import traceback
            print(traceback.format_exc())
            return None

    def sauvegarder_resultats_temporaires(self, resultats):
        """Sauvegarde temporaire des résultats"""
        df_temp = pd.DataFrame(resultats)
        temp_path = os.path.join(self.chemin_base, "plats_populaires_nutriments_temp.csv")
        df_temp.to_csv(temp_path, index=False, encoding='utf-8-sig', sep=',')

    def finaliser_analyse(self, resultats):
        """Finalise l'analyse et sauvegarde les résultats"""
        df_nutriments = pd.DataFrame(resultats)
        df_nutriments.to_csv(self.chemin_sortie, index=False, encoding='utf-8-sig', sep=',')
        
        print("\nMoyennes nutritionnelles par pays :")
        colonnes_nutriments = list(self.nutriments_cibles.values())
        stats_pays = df_nutriments.groupby('Pays')[colonnes_nutriments].mean()
        print(stats_pays.round(2))
        
        return df_nutriments

if __name__ == "__main__":
    print("=== ANALYSE NUTRITIONNELLE DES PLATS TRADITIONNELS ===")
    analyzer = NutrientAnalyzer()
    df_resultat = analyzer.analyser_plats()
# Out:
# === ANALYSE NUTRITIONNELLE DES PLATS TRADITIONNELS ===
# Dataset chargé avec succès : 42 plats
#
# Analyse du plat 1/42 : Beef Brisket Pot Roast
#   Analyse de : Beef Brisket (20412.0 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Onion (450.0 g)
#   Analyse de : Garlic (5000.0 ml)
#   Analyse de : Thyme (1.0 g)
#   Analyse de : Rosemary (1.0 g)
#   Analyse de : Bay Leaves (4.0 portion)
#   Analyse de : beef stock (480.0 ml)
#   Analyse de : Carrots (540.0 g)
#   Analyse de : Mustard (15.0 ml)
#   Analyse de : Potatoes (600.0 g)
#
# Analyse du plat 2/42 : Big Mac
#   Analyse de : Minced Beef (400.0 g)
#   Analyse de : Olive Oil (30.0 ml)
#   Analyse de : Sesame Seed Burger Buns (120.0 g)
#   Analyse de : Onion (150 g)
#   Analyse de : Iceberg Lettuce (50 g)
#   Analyse de : Cheese (2000.0 ml)
#   Analyse de : Dill Pickles (3.0 portion)
#   Analyse de : Mayonnaise (240.0 ml)
#   Analyse de : White Wine Vinegar (10.0 ml)
#   Analyse de : Pepper (120 g)
#   Analyse de : Mustard (10.0 ml)
#   Analyse de : Onion Salt (5.0 ml)
#   Analyse de : Garlic Powder (5.0 ml)
#   Analyse de : Paprika (1 portion)
#
# Analyse du plat 3/42 : Chicken Fajita Mac and Cheese
#   Analyse de : macaroni (500.0 g)
#   Analyse de : chicken stock (480.0 ml)
#   Analyse de : heavy cream (240 g)
#   Analyse de : fajita seasoning (1.0 portion)
#   Analyse de : salt (5.0 ml)
#   Analyse de : chicken breast (510.0 g)
#   Analyse de : olive oil (30.0 ml)
#   Analyse de : onion (750.0 ml)
#   Analyse de : red pepper (2000.0 ml)
#   Analyse de : garlic (2000.0 ml)
#   Analyse de : cheddar cheese (240.0 ml)
#   Analyse de : parsley (5 g)
#
# Analyse du plat 4/42 : Chick-Fil-A Sandwich
#   Analyse de : Chicken Breast (170.0 g)
#   Analyse de : Pickle Juice (1 portion)
#   Analyse de : Egg (50.0 g)
#   Analyse de : Milk (1 portion)
#   Analyse de : Flour (120 g)
#   Analyse de : Icing Sugar (15.0 ml)
#   Analyse de : Paprika (1 portion)
#   Analyse de : Salt (1 portion)
#   Analyse de : Black Pepper (120 g)
#   Analyse de : Garlic Powder (5 g)
#   Analyse de : Celery Salt (40 g)
#   Analyse de : Cayenne Pepper (120 g)
#   Analyse de : Olive Oil (240.0 ml)
#   Analyse de : Sesame Seed Burger Buns (60.0 g)
#
# Analyse du plat 5/42 : Mac and Cheese
#   Analyse de : macaroni (500.0 g)
#   Analyse de : chicken stock (480.0 ml)
#   Analyse de : heavy cream (240 g)
#   Analyse de : fajita seasoning (1.0 portion)
#   Analyse de : salt (5.0 ml)
#   Analyse de : chicken breast (510.0 g)
#   Analyse de : olive oil (30.0 ml)
#   Analyse de : onion (750.0 ml)
#   Analyse de : red pepper (2000.0 ml)
#   Analyse de : garlic (2000.0 ml)
#   Analyse de : cheddar cheese (240.0 ml)
#   Analyse de : parsley (5 g)
#
# Analyse du plat 6/42 : Pancakes
#   Analyse de : Flour (100.0 g)
#   Analyse de : Eggs (150.0 g)
#   Analyse de : Milk (300.0 ml)
#   Analyse de : Sunflower Oil (1000.0 ml)
#   Analyse de : Sugar (4 g)
#   Analyse de : Raspberries (1 portion)
#   Analyse de : Blueberries (1 portion)
#
# Analyse du plat 7/42 : Pizza Express Margherita
#   Analyse de : Water (150.0 ml)
#   Analyse de : Sugar (5.0 ml)
#   Analyse de : Yeast (15.0 g)
#   Analyse de : Plain Flour (225.0 g)
#   Analyse de : Salt (5.0 ml)
#   Analyse de : Olive Oil (15 g)
#   Analyse de : Passata (80.0 g)
#   Analyse de : Mozzarella (70.0 g)
#   Analyse de : Oregano (2 g)
#   Analyse de : Basil (5 g)
#   Analyse de : Black Pepper (120 g)
#
# Analyse du plat 8/42 : Beef Lo Mein
#   Analyse de : Beef (200 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Pepper (120 g)
#   Analyse de : Sesame Seed Oil (10.0 ml)
#   Analyse de : Egg (50 g)
#   Analyse de : Starch (45.0 ml)
#   Analyse de : Oil (75.0 ml)
#   Analyse de : Noodles (85 g)
#   Analyse de : Onion (150 g)
#   Analyse de : Minced Garlic (5.0 ml)
#   Analyse de : Ginger (5.0 ml)
#   Analyse de : Bean Sprouts (240.0 ml)
#   Analyse de : Mushrooms (240.0 ml)
#   Analyse de : Water (240.0 ml)
#   Analyse de : Oyster Sauce (15.0 ml)
#   Analyse de : Sugar (5.0 ml)
#   Analyse de : Soy Sauce (5.0 ml)
#
# Analyse du plat 9/42 : Chicken Congee
#   Analyse de : Chicken (226.8 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Pepper (120 g)
#   Analyse de : Ginger Cordial (5.0 ml)
#   Analyse de : Ginger (5.0 ml)
#   Analyse de : Spring Onions (15.0 ml)
#   Analyse de : Rice (75 g)
#   Analyse de : Water (1920.0 ml)
#   Analyse de : Coriander (56.7 g)
#
# Analyse du plat 10/42 : Egg Drop Soup
#   Analyse de : Chicken Stock (720.0 ml)
#   Analyse de : Salt (1 portion)
#   Analyse de : Sugar (4 g)
#   Analyse de : Pepper (120 g)
#   Analyse de : Sesame Seed Oil (5.0 ml)
#   Analyse de : Peas (80 g)
#   Analyse de : Mushrooms (15 g)
#   Analyse de : Cornstarch (15.0 ml)
#   Analyse de : Water (30.0 ml)
#   Analyse de : Spring Onions (150 g)
#
# Analyse du plat 11/42 : General Tso's Chicken
#   Analyse de : Chicken Breast (170.0 g)
#   Analyse de : Plain Flour (120 g)
#   Analyse de : Egg (50.0 g)
#   Analyse de : Starch (30.0 ml)
#   Analyse de : Baking Powder (15.0 ml)
#   Analyse de : Salt (5.0 ml)
#   Analyse de : Onion Salt (150 g)
#   Analyse de : Garlic Powder (5 g)
#   Analyse de : Water (240 g)
#   Analyse de : Chicken Stock (150 g)
#   Analyse de : Duck Sauce (200 g)
#   Analyse de : Soy Sauce (45.0 ml)
#   Analyse de : Honey (30.0 ml)
#   Analyse de : Rice Vinegar (15.0 ml)
#   Analyse de : Sesame Seed Oil (30.0 ml)
#   Analyse de : Gochujang (1 portion)
#   Analyse de : Starch (30.0 ml)
#   Analyse de : Garlic (1000.0 ml)
#   Analyse de : Spring Onions (300.0 g)
#   Analyse de : Ginger (5.0 ml)
#
# Analyse du plat 12/42 : Kung Pao Chicken
#   Analyse de : Sake (30.0 ml)
#   Analyse de : Soy Sauce (30.0 ml)
#   Analyse de : Sesame Seed Oil (30.0 ml)
#   Analyse de : Corn Flour (30.0 ml)
#   Analyse de : Water (30.0 ml)
#   Analyse de : Chicken (500.0 g)
#   Analyse de : Chilli Powder (15.0 ml)
#   Analyse de : Rice Vinegar (5.0 ml)
#   Analyse de : Brown Sugar (15.0 ml)
#   Analyse de : Spring Onions (600.0 g)
#   Analyse de : Garlic Clove (6000.0 ml)
#   Analyse de : Water Chestnut (220.0 g)
#   Analyse de : Peanuts (100.0 g)
#
# Analyse du plat 13/42 : Ma Po Tofu
#   Analyse de : Tofu (450.0 g)
#   Analyse de : Minced Beef (100.0 g)
#   Analyse de : Sesame Seed Oil (1 portion)
#   Analyse de : Doubanjiang (5.0 ml)
#   Analyse de : Fermented Black Beans (1 portion)
#   Analyse de : Pepper (15.0 ml)
#   Analyse de : Salt (1 portion)
#   Analyse de : Sichuan pepper (120 g)
#   Analyse de : Soy Sauce (15.0 ml)
#   Analyse de : Water (400.0 ml)
#   Analyse de : Olive Oil (30.0 ml)
#   Analyse de : Scallions (30.0 g)
#   Analyse de : Spring Onions (600.0 g)
#   Analyse de : Garlic (2000.0 ml)
#   Analyse de : Ginger (4000.0 ml)
#   Analyse de : Water (30.0 ml)
#   Analyse de : Cornstarch (15.0 ml)
#
# Analyse du plat 14/42 : Sweet and Sour Pork
#   Analyse de : Pork (200.0 g)
#   Analyse de : Egg (50.0 g)
#   Analyse de : Water (240 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Sugar (5.0 ml)
#   Analyse de : Soy Sauce (10.0 g)
#   Analyse de : Starch (10.0 g)
#   Analyse de : Tomato Puree (30.0 g)
#   Analyse de : Vinegar (10.0 g)
#   Analyse de : Coriander (5 g)
#
# Analyse du plat 15/42 : Coq au Vin
#   Analyse de : Olive Oil (15.0 ml)
#   Analyse de : Bacon (90.0 g)
#   Analyse de : Shallots (9.0 portion)
#   Analyse de : Chicken Legs (460.0 g)
#   Analyse de : Chicken Thighs (640.0 g)
#   Analyse de : Chicken Breasts (340.0 g)
#   Analyse de : Garlic (3000.0 ml)
#   Analyse de : Brandy (45.0 ml)
#   Analyse de : Red Wine (600.0 ml)
#   Analyse de : Chicken Stock (150.0 ml)
#   Analyse de : tomato puree (10.0 ml)
#   Analyse de : thyme (3.0 g)
#   Analyse de : Rosemary (2.0 g)
#   Analyse de : bay leaves (2.0 portion)
#   Analyse de : parsley (5 g)
#   Analyse de : chestnut mushroom (250.0 g)
#   Analyse de : plain flour (30.0 ml)
#   Analyse de : butter (5.0 ml)
#
# Analyse du plat 16/42 : French Onion Soup
#   Analyse de : Butter (50.0 g)
#   Analyse de : Olive Oil (15.0 ml)
#   Analyse de : Onion (1000.0 g)
#   Analyse de : Sugar (5.0 ml)
#   Analyse de : Garlic Clove (4000.0 ml)
#   Analyse de : Plain Flour (30.0 ml)
#   Analyse de : Dry White Wine (250.0 ml)
#   Analyse de : Beef Stock (1000.0 ml)
#   Analyse de : Bread (4000.0 ml)
#   Analyse de : Gruyère (140.0 g)
#
# Analyse du plat 17/42 : Ratatouille
#   Analyse de : Aubergine (750.0 g)
#   Analyse de : Courgettes (800.0 g)
#   Analyse de : Yellow Pepper (240.0 g)
#   Analyse de : Tomato (720.0 g)
#   Analyse de : Olive Oil (75.0 ml)
#   Analyse de : Basil (5 g)
#   Analyse de : Onion (150.0 g)
#   Analyse de : Garlic Clove (3000.0 ml)
#   Analyse de : Red Wine Vinegar (5.0 ml)
#   Analyse de : Sugar (5.0 ml)
#
# Analyse du plat 18/42 : Tarte Tatin
#   Analyse de : Puff Pastry (300.0 g)
#   Analyse de : Plain Flour (120 g)
#   Analyse de : Braeburn Apples (6.0 portion)
#   Analyse de : Caster Sugar (100.0 g)
#   Analyse de : Butter (85.0 g)
#   Analyse de : Creme Fraiche (1 portion)
#
# Analyse du plat 19/42 : Duck Confit
#   Analyse de : Sea Salt (1 portion)
#   Analyse de : Bay Leaf (4.0 g)
#   Analyse de : Garlic (4000.0 ml)
#   Analyse de : Thyme (2 g)
#   Analyse de : Duck Legs (800.0 g)
#   Analyse de : White Wine (100.0 ml)
#
# Analyse du plat 20/42 : Gigantes Plaki
#   Analyse de : Butter Beans (400.0 g)
#   Analyse de : Olive Oil (45.0 ml)
#   Analyse de : Onion (150.0 g)
#   Analyse de : Garlic Clove (10.0 g)
#   Analyse de : Tomato Puree (30.0 ml)
#   Analyse de : Tomatoes (800.0 g)
#   Analyse de : Sugar (15.0 ml)
#   Analyse de : Dried Oregano (15.0 ml)
#   Analyse de : Cinnamon (1 portion)
#   Analyse de : Chopped Parsley (30.0 ml)
#
# Analyse du plat 21/42 : Greek Salad
#   Analyse de : Quinoa (225.0 g)
#   Analyse de : Butter (25.0 g)
#   Analyse de : Red Chilli (1.0 portion)
#   Analyse de : Garlic (1000.0 ml)
#   Analyse de : Chicken Breast (400.0 g)
#   Analyse de : Olive Oil (30.0 ml)
#   Analyse de : Black Olives (1 portion)
#   Analyse de : Red Onions (150.0 g)
#   Analyse de : Feta (100.0 g)
#   Analyse de : Mint (5 g)
#   Analyse de : Lemon (1 portion)
#
# Analyse du plat 22/42 : Moussaka
#   Analyse de : Beef (500.0 g)
#   Analyse de : Aubergine (375.0 g)
#   Analyse de : Greek Yogurt (150.0 g)
#   Analyse de : Egg (50.0 g)
#   Analyse de : Parmesan (45.0 ml)
#   Analyse de : Tomato (400.0 g)
#   Analyse de : Tomato Puree (60.0 ml)
#   Analyse de : Potatoes (350.0 g)
#
# Analyse du plat 23/42 : Souvlaki
#   Analyse de : Garlic (2000.0 ml)
#   Analyse de : Sea Salt (10.0 ml)
#   Analyse de : Olive Oil (60.0 ml)
#   Analyse de : Lemon (1 portion)
#   Analyse de : Dill (15.0 ml)
#   Analyse de : Lamb Leg (750.0 g)
#   Analyse de : Pita Bread (30 g)
#
# Analyse du plat 24/42 : Tzatziki
#   Analyse de : Bulgur Wheat (25.0 g)
#   Analyse de : Lamb Mince (500.0 g)
#   Analyse de : Cumin (5.0 ml)
#   Analyse de : Coriander (5.0 ml)
#   Analyse de : Paprika (5.0 ml)
#   Analyse de : Garlic (1000.0 ml)
#   Analyse de : Olive Oil (15 g)
#   Analyse de : Bun (4.0 portion)
#   Analyse de : Cucumber (1 portion)
#   Analyse de : Greek Yogurt (200.0 g)
#   Analyse de : Mint (30.0 ml)
#
# Analyse du plat 25/42 : Garides Saganaki
#   Analyse de : Raw king prawns (500.0 g)
#   Analyse de : Olive oil (45.0 g)
#   Analyse de : Chopped onion (150.0 g)
#   Analyse de : Freshly chopped parsley (5 g)
#   Analyse de : White wine (250.0 ml)
#   Analyse de : Chopped tomatoes (120.0 g)
#   Analyse de : Minced garlic (5 g)
#   Analyse de : Cubed Feta cheese (30.0 g)
#
# Analyse du plat 26/42 : Dal Fry
#   Analyse de : Toor dal (240.0 ml)
#   Analyse de : Water (240 g)
#   Analyse de : Salt (5.0 ml)
#   Analyse de : Turmeric (1 portion)
#   Analyse de : Ghee (45.0 ml)
#   Analyse de : Chopped tomatoes (240.0 ml)
#   Analyse de : Cumin seeds (1 portion)
#   Analyse de : Mustard Seeds (15 g)
#   Analyse de : Bay Leaf (2.0 g)
#   Analyse de : Green Chilli (15.0 ml)
#   Analyse de : Ginger (10.0 ml)
#   Analyse de : Cilantro (30.0 ml)
#   Analyse de : Red Pepper (120 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Sugar (5.0 ml)
#   Analyse de : Garam Masala (1 portion)
#
# Analyse du plat 27/42 : Rogan Josh
#   Analyse de : Onion (1892.0 ml)
#   Analyse de : Sunflower Oil (60.0 ml)
#   Analyse de : Garlic (4000.0 ml)
#   Analyse de : Ginger (15 g)
#   Analyse de : Madras Paste (30.0 ml)
#   Analyse de : Paprika (10.0 ml)
#   Analyse de : cinnamon stick (1.0 portion)
#   Analyse de : Cardamom (6000.0 ml)
#   Analyse de : Cloves (4.0 portion)
#   Analyse de : Bay Leaf (2.0 g)
#   Analyse de : Tomato Purée (15.0 ml)
#   Analyse de : Lamb (1000.0 g)
#   Analyse de : Greek yogurt (150.0 ml)
#   Analyse de : Coriander (5 g)
#
# Analyse du plat 28/42 : Tandoori Chicken
#   Analyse de : lemons (2.0 portion)
#   Analyse de : paprika (20.0 ml)
#   Analyse de : red onions (2000.0 ml)
#   Analyse de : chicken thighs (16000.0 ml)
#   Analyse de : vegetable oil (1 portion)
#   Analyse de : Greek yogurt (300.0 ml)
#   Analyse de : ginger (22.5 g)
#   Analyse de : garlic clove (20.0 g)
#   Analyse de : garam masala (1 portion)
#   Analyse de : ground cumin (1 portion)
#   Analyse de : chilli powder (1 portion)
#   Analyse de : turmeric (1 portion)
#
# Analyse du plat 29/42 : Biryani
#   Analyse de : Cashew nuts (12.0 portion)
#   Analyse de : Khus khus (1 portion)
#   Analyse de : Cumin seeds (1 portion)
#   Analyse de : Onions (3000.0 ml)
#   Analyse de : Ginger garlic paste (10.0 ml)
#   Analyse de : Garlic (4000.0 ml)
#   Analyse de : Mint (5 g)
#   Analyse de : Cilantro (1 portion)
#   Analyse de : Saffron (1 portion)
#   Analyse de : Ghee (30.0 ml)
#   Analyse de : Basmati rice (480.0 ml)
#   Analyse de : Full fat yogurt (1 portion)
#   Analyse de : Cumin Seeds (15.0 ml)
#   Analyse de : Bay leaf (1 g)
#   Analyse de : Cinnamon (1.0 g)
#   Analyse de : Cloves (3.0 portion)
#   Analyse de : Cardamom (2.0 portion)
#   Analyse de : Lamb (1000.0 ml)
#   Analyse de : Red Chilli powder (5.0 ml)
#   Analyse de : Biryani masala (15.0 ml)
#
# Analyse du plat 30/42 : Carbonara
#   Analyse de : Spaghetti (320.0 g)
#   Analyse de : Egg Yolks (300.0 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Bacon (150.0 g)
#   Analyse de : Pecorino (50.0 g)
#   Analyse de : Black Pepper (120 g)
#
# Analyse du plat 31/42 : Lasagna
#   Analyse de : green red lentils (240.0 ml)
#   Analyse de : Carrots (120.0 g)
#   Analyse de : onion (150.0 g)
#   Analyse de : zucchini (150.0 g)
#   Analyse de : coriander (5 g)
#   Analyse de : spinach (150.0 g)
#   Analyse de : lasagne sheets (10.0 portion)
#   Analyse de : vegan butter (35.0 g)
#   Analyse de : flour (60.0 g)
#   Analyse de : soya milk (300.0 ml)
#   Analyse de : mustard (7.5 g)
#   Analyse de : vinegar (5.0 g)
#
# Analyse du plat 32/42 : Osso Buco
#   Analyse de : Veal (4.0 portion)
#   Analyse de : Flour (120 g)
#   Analyse de : Olive Oil (30.0 g)
#   Analyse de : Butter (45.0 g)
#   Analyse de : Onion (1.0 g)
#   Analyse de : Carrots (1.0 g)
#   Analyse de : Celery (1.0 g)
#   Analyse de : Fennel (1000.0 ml)
#   Analyse de : Garlic (3000.0 ml)
#   Analyse de : Orange Zest (2.0 portion)
#   Analyse de : Marjoram (5.0 g)
#   Analyse de : Bay Leaf (1.0 g)
#   Analyse de : Dry White Wine (240.0 ml)
#   Analyse de : Chicken Stock (150 g)
#   Analyse de : Tomatoes (240.0 ml)
#   Analyse de : Parsley (30.0 g)
#   Analyse de : Garlic (5.0 g)
#   Analyse de : Lemon Zest (5.0 g)
#
# Analyse du plat 33/42 : Risotto
#   Analyse de : butter (14 g)
#   Analyse de : onion (1000.0 ml)
#   Analyse de : rice (150.0 g)
#   Analyse de : white wine (125.0 ml)
#   Analyse de : vegetable stock (1000.0 ml)
#   Analyse de : lemon (1 portion)
#   Analyse de : King Prawns (360.0 g)
#   Analyse de : salmon (150.0 g)
#   Analyse de : asparagus (100000.0 ml)
#   Analyse de : black pepper (120 g)
#   Analyse de : Parmesan (50.0 g)
#
# Analyse du plat 34/42 : Spaghetti Bolognese
#   Analyse de : onions (300.0 g)
#   Analyse de : olive oil (15.0 ml)
#   Analyse de : garlic (1000.0 ml)
#   Analyse de : lean minced beef (500.0 g)
#   Analyse de : mushrooms (90.0 g)
#   Analyse de : dried oregano (5.0 ml)
#   Analyse de : tomatoes (400.0 g)
#   Analyse de : hot beef stock (300.0 ml)
#   Analyse de : tomato puree (15.0 ml)
#   Analyse de : worcestershire sauce (15.0 ml)
#   Analyse de : spaghetti (350.0 g)
#   Analyse de : parmesan (25 g)
#
# Analyse du plat 35/42 : Sushi
#   Analyse de : Sushi Rice (300.0 ml)
#   Analyse de : Rice wine (100.0 ml)
#   Analyse de : Caster Sugar (30.0 ml)
#   Analyse de : Mayonnaise (45.0 ml)
#   Analyse de : Rice wine (15.0 ml)
#   Analyse de : Soy Sauce (15.0 ml)
#   Analyse de : Cucumber (1.0 portion)
#
# Analyse du plat 36/42 : Teriyaki Chicken
#   Analyse de : soy sauce (15 g)
#   Analyse de : water (240 g)
#   Analyse de : brown sugar (4 g)
#   Analyse de : ground ginger (15 g)
#   Analyse de : minced garlic (5 g)
#   Analyse de : cornstarch (60.0 g)
#   Analyse de : chicken breasts (340.0 g)
#   Analyse de : stir-fry vegetables (1.0 portion)
#   Analyse de : brown rice (720.0 ml)
#
# Analyse du plat 37/42 : Tonkatsu
#   Analyse de : Pork Chops (800.0 g)
#   Analyse de : Flour (100.0 g)
#   Analyse de : Eggs (100.0 g)
#   Analyse de : Breadcrumbs (100.0 g)
#   Analyse de : Vegetable Oil (1 portion)
#   Analyse de : Tomato Ketchup (30.0 ml)
#   Analyse de : Worcestershire Sauce (30.0 ml)
#   Analyse de : Oyster Sauce (15.0 ml)
#   Analyse de : Caster Sugar (2000.0 ml)
#
# Analyse du plat 38/42 : Udon
#   Analyse de : Udon Noodles (250.0 g)
#   Analyse de : Sesame Seed Oil (30.0 ml)
#   Analyse de : Onion (1000.0 ml)
#   Analyse de : Cabbage (37.5 g)
#   Analyse de : Shiitake Mushrooms (150.0 g)
#   Analyse de : Spring Onions (600.0 g)
#   Analyse de : Mirin (60.0 ml)
#   Analyse de : Soy Sauce (30.0 ml)
#   Analyse de : Caster Sugar (1000.0 ml)
#   Analyse de : Worcestershire Sauce (1000.0 ml)
#
# Analyse du plat 39/42 : Paella
#   Analyse de : Baby Aubergine (1125.0 g)
#   Analyse de : Fennel (3.0 portion)
#   Analyse de : Red Pepper (1000.0 ml)
#   Analyse de : Courgettes (200.0 g)
#   Analyse de : Onion (1000.0 ml)
#   Analyse de : Paella Rice (300.0 g)
#   Analyse de : Paprika (5.0 ml)
#   Analyse de : Saffron (1 portion)
#   Analyse de : White Wine (200.0 ml)
#   Analyse de : Vegetable Stock (700.0 ml)
#   Analyse de : Frozen Peas (100.0 g)
#   Analyse de : Lemon (1.0 portion)
#   Analyse de : Parsley (5 g)
#   Analyse de : Salt (1 portion)
#   Analyse de : Black Pepper (120 g)
#
# Analyse du plat 40/42 : Pisto
#   Analyse de : Rapeseed Oil (15.0 ml)
#   Analyse de : Leek (2000.0 ml)
#   Analyse de : Courgettes (300.0 g)
#   Analyse de : Vegetable Stock (1000.0 ml)
#   Analyse de : Cannellini Beans (400.0 g)
#   Analyse de : Green Beans (200.0 g)
#   Analyse de : Tomatoes (360.0 g)
#   Analyse de : Garlic Clove (15.0 g)
#   Analyse de : Basil (3.75 g)
#   Analyse de : Parmesan (40.0 g)
#
# Analyse du plat 41/42 : Green Curry
#   Analyse de : Potatoes (225.0 g)
#   Analyse de : green beans (100.0 g)
#   Analyse de : sunflower oil (15.0 ml)
#   Analyse de : garlic (1000.0 ml)
#   Analyse de : Thai green curry paste (20.0 ml)
#   Analyse de : coconut milk (400.0 ml)
#   Analyse de : Thai fish sauce (10.0 ml)
#   Analyse de : Sugar (5.0 ml)
#   Analyse de : Chicken (450000.0 ml)
#   Analyse de : lime (2000.0 ml)
#   Analyse de : basil (5 g)
#   Analyse de : Rice (75 g)
#
# Analyse du plat 42/42 : Pad See Ew
#   Analyse de : rice stick noodles (75 g)
#   Analyse de : dark soy sauce (30.0 ml)
#   Analyse de : oyster sauce (30.0 ml)
#   Analyse de : soy sauce (10.0 ml)
#   Analyse de : white vinegar (10.0 ml)
#   Analyse de : sugar (10.0 ml)
#   Analyse de : water (30.0 ml)
#   Analyse de : peanut oil (30.0 ml)
#   Analyse de : garlic (2000.0 ml)
#   Analyse de : Chicken (240.0 ml)
#   Analyse de : Egg (50.0 g)
#   Analyse de : Chinese broccoli (960.0 ml)
#
# Moyennes nutritionnelles par pays :
#             Protéines (g)  Lipides (g)  Glucides (g)  Calories (kcal)  \
# Pays
# CHINE              148.78       187.39        159.68          2476.32
# ESPAGNE            117.52       140.82        400.00          3000.00
# FRANCE             154.70       232.72        334.85          3000.00
# GRÈCE              137.79       178.72        179.54          2565.33
# INDE               258.60       242.94        303.99          2867.30
# ITALIE             174.28       203.71        234.27          2611.76
# JAPON               91.83        74.65        271.96          2181.80
# THAÏLANDE          207.34       250.00        268.54          3000.00
# ÉTATS-UNIS         195.12       227.71        249.24          2811.71
#
#             Fibres (g)  Sucres (g)
# Pays
# CHINE            22.39         0.0
# ESPAGNE          50.00         0.0
# FRANCE           31.60         0.0
# GRÈCE            16.85         0.0
# INDE             45.69         0.0
# ITALIE           33.48         0.0
# JAPON            21.60         0.0
# THAÏLANDE        28.94         0.0
# ÉTATS-UNIS       27.82         0.0
